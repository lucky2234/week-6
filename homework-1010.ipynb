# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(0,180,1000)
y = np.sin(x*np.pi/180)
z = y

noise = np.random.random(1000)
y = y + noise/10.
#plt.plot(x,y)

# 计算出平均的噪声，标准差
noise = y - z 
np.mean(noise),np.std(noise)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
ploy = np.polyfit(x,y,10)
#print(ploy)
repaired = -3.46799778e-21*(x**10)+3.73795976e-18*(x**9)-1.65853882e-15*(x**8)+3.96739893e-13*(x**7)-5.58664914e-11*(x**6)+4.71599594e-09*(x**5)-2.27459579e-07*(x**4)+4.68141692e-06*(x**3)-4.46415462e-05*(x**2)+0.0172443702*(x**1)+0.0494840621
ax2.plot(x,repaired,"b")
s = y - repaired
ax1.plot(x, s, "r")
ax2.plot(x, z, "r")
print(np.mean(s),np.std(s))
# Out:
# -0.0015427470015024211 0.028615393543515954
